# %%
import pandas as pd
import glob
import numpy as np

# %%
glob.os.getcwd()
# Out:
# 'C:\\Users\\wesdyer\\Dropbox\\Wes Dyer\\Classes\\Agron_Sci_Programming\\notes'

# %%
df = pd.read_csv('C:\\Users\\wesdyer\\Dropbox\\Wes Dyer\\Classes\\Agron_Sci_Programming\\notes\\ok_mesonet_8_apr_2019.csv')
df.head()
# Out:
#    STID     NAME  ST    LAT    LON    YR  MO  DA  HR  MI  ... RELH CHIL HEAT  \
# 0  ACME     Acme  OK  34.81 -98.02  2019   4  15  15  20  ...
# 1  ADAX      Ada  OK  34.80 -96.67  2019   4  15  15  20  ...   40
# 2  ALTU    Altus  OK  34.59 -99.34  2019   4  15  15  20  ...   39        82
# 3  ALV2     Alva  OK  36.71 -98.71  2019   4  15  15  20  ...   32        82
# 4  ANT2  Antlers  OK  34.25 -95.67  2019   4  15  15  20  ...   35
#
#   WDIR WSPD WMAX     PRES TMAX TMIN RAIN
# 0
# 1    S   12   20  1011.13   78   48
# 2  SSW   19   26  1007.86   82   45
# 3    S   20   26  1004.65   84   40
# 4    S   11   20  1013.64   78   38
#
# [5 rows x 22 columns]

# %%
df.loc[0, 'RAIN']
# Out:
# ' '

# %%
df.replace('', np.nan, inplace = True)
df
# Out:
#      STID       NAME  ST    LAT    LON    YR  MO  DA  HR  MI  ... RELH CHIL  \
# 0    ACME       Acme  OK  34.81 -98.02  2019   4  15  15  20  ...
# 1    ADAX        Ada  OK  34.80 -96.67  2019   4  15  15  20  ...   40
# 2    ALTU      Altus  OK  34.59 -99.34  2019   4  15  15  20  ...   39
# 3    ALV2       Alva  OK  36.71 -98.71  2019   4  15  15  20  ...   32
# 4    ANT2    Antlers  OK  34.25 -95.67  2019   4  15  15  20  ...   35
# ..    ...        ...  ..    ...    ...   ...  ..  ..  ..  ..  ...  ...  ...
# 115  WILB  Wilburton  OK  34.90 -95.35  2019   4  15  15  20  ...   39
# 116  WIST     Wister  OK  34.98 -94.69  2019   4  15  15  20  ...   39
# 117  WOOD   Woodward  OK  36.42 -99.42  2019   4  15  15  20  ...   23
# 118  WYNO     Wynona  OK  36.52 -96.34  2019   4  15  15  20  ...   36
# 119  YUKO      Yukon  OK  35.56 -97.76  2019   4  15  15  20  ...   38
#
#     HEAT WDIR WSPD WMAX     PRES TMAX TMIN RAIN
# 0
# 1           S   12   20  1011.13   78   48
# ...

# %%
idx_acme = df['STID'] == 'ACME'
df[idx_acme]
# Out:
#    STID  NAME  ST    LAT    LON    YR  MO  DA  HR  MI  ... RELH CHIL HEAT  \
# 0  ACME  Acme  OK  34.81 -98.02  2019   4  15  15  20  ...
#
#   WDIR WSPD WMAX PRES TMAX TMIN RAIN
# 0
#
# [1 rows x 22 columns]

# %%
df [df ['STID']=='ACME'] #same as above
# Out:
#    STID  NAME  ST    LAT    LON    YR  MO  DA  HR  MI  ... RELH CHIL HEAT  \
# 0  ACME  Acme  OK  34.81 -98.02  2019   4  15  15  20  ...
#
#   WDIR WSPD WMAX PRES TMAX TMIN RAIN
# 0
#
# [1 rows x 22 columns]

# %%
idx_starts_with_A = df['STID'].str.match('A')
df[idx_starts_with_A]
# Out:
#    STID     NAME  ST    LAT    LON    YR  MO  DA  HR  MI  ... RELH CHIL HEAT  \
# 0  ACME     Acme  OK  34.81 -98.02  2019   4  15  15  20  ...
# 1  ADAX      Ada  OK  34.80 -96.67  2019   4  15  15  20  ...   40
# 2  ALTU    Altus  OK  34.59 -99.34  2019   4  15  15  20  ...   39        82
# 3  ALV2     Alva  OK  36.71 -98.71  2019   4  15  15  20  ...   32        82
# 4  ANT2  Antlers  OK  34.25 -95.67  2019   4  15  15  20  ...   35
# 5  APAC   Apache  OK  34.91 -98.29  2019   4  15  15  20  ...   41
# 6  ARD2  Ardmore  OK  34.19 -97.09  2019   4  15  15  20  ...   41
# 7  ARNE   Arnett  OK  36.07 -99.90  2019   4  15  15  20  ...   10        85
#
#   WDIR WSPD WMAX     PRES TMAX TMIN RAIN
# 0
# 1    S   12   20  1011.13   78   48
# 2  SSW   19   26  1007.86   82   45
# 3    S   20   26  1004.65   84   40
# 4    S   11   20  1013.64   78   38
# 5    S   23   29   1008.9   80   49
# 6    S   18   26  1011.43   77   50
# 7   SW   22   32  1005.13
#
# [8 rows x 22 columns]
